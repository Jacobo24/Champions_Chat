# %%
pip install langchain langchain-community sentence-transformers chromadb
# Out:
# Requirement already satisfied: langchain in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (1.1.3)
# Requirement already satisfied: langchain-community in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: sentence-transformers in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (5.1.2)
# Requirement already satisfied: chromadb in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (1.3.6)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain) (1.1.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (0.4.58)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: certifi in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: filelock in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.15)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: coloredlogs in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: greenlet>=1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.2->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: pyreadline3 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\usuario\onedrive\documentos\github\champions_chat\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path
import json

from langchain_community.chat_models import ChatOllama
from langchain_community.embeddings import SentenceTransformerEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
import re


# Text splitter (para hacer chunks)
try:
    from langchain.text_splitter import RecursiveCharacterTextSplitter
except Exception:
    from langchain_text_splitters import RecursiveCharacterTextSplitter  # alternativa según versión


# Modelo de Ollama que quieres usar
LLM_MODEL_NAME = "deepseek-r1:8b"   # o "llama3:8b" si prefieres

# Rutas a tus JSONL (ajusta la carpeta si la tienes en otra ubicación)
DATA_DIR = Path("../.jsonl")
FINALS_PATH  = DATA_DIR / "finals.jsonl"
HISTORY_PATH = DATA_DIR / "history.jsonl"
PLAYERS_PATH = DATA_DIR / "players.jsonl"
TEAMS_PATH   = DATA_DIR / "teams.jsonl"
COACHES_PATH = DATA_DIR / "coaches.jsonl"

# %%
def load_jsonl(path: Path):
    """Carga un .jsonl (un JSON por línea) y devuelve una lista de dicts."""
    data = []
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            data.append(json.loads(line))
    return data


finals_data  = load_jsonl(FINALS_PATH)
history_data = load_jsonl(HISTORY_PATH)
players_data = load_jsonl(PLAYERS_PATH)
teams_data   = load_jsonl(TEAMS_PATH)
coaches_data = load_jsonl(COACHES_PATH)

len(finals_data), len(history_data), len(players_data), len(teams_data), len(coaches_data)
# Out:
# (46, 31, 24, 18, 19)

# %%
import re
import unicodedata
import json

def norm(s: str) -> str:
    if not s:
        return ""
    s = s.strip()
    s = "".join(c for c in unicodedata.normalize("NFD", s) if unicodedata.category(c) != "Mn")
    return s

def guess_coach_name(obj: dict) -> str:
    # intenta varios campos típicos
    for key in ["coach_name", "name", "entrenador", "full_name", "person_name"]:
        if obj.get(key):
            return str(obj[key]).strip()
    # fallback: intenta extraer del título "Perfil de X"
    title = obj.get("titulo") or ""
    m = re.search(r"perfil.*?de\s+(.+)$", title, flags=re.IGNORECASE)
    if m:
        return m.group(1).strip()
    return ""

def extract_candidate_clubs(text: str, known_clubs: list[str] | None = None) -> list[str]:
    """
    Opcional: si pasas una lista de clubes del dataset (team_name),
    los detecta dentro del texto y los coloca como tokens.
    """
    if not text:
        return []
    if not known_clubs:
        return []
    t = norm(text).lower()
    found = []
    for club in known_clubs:
        if norm(club).lower() in t:
            found.append(club)
    return found

def render_coach_doc(obj: dict, known_clubs: list[str] | None = None) -> str:
    coach = guess_coach_name(obj)
    titulo = obj.get("titulo") or ""
    texto = obj.get("texto") or ""
    season = obj.get("season_year")

    clubs = extract_candidate_clubs(texto, known_clubs)
    clubs_str = " | ".join(clubs) if clubs else "N/A"

    # ✅ cabecera “token heavy” (mejora retrieval)
    header_lines = [
        f"CATEGORIA: coach",
        f"ENTRENADOR: {coach if coach else 'N/A'}",
        f"TITULO: {titulo}",
        f"TEMPORADA: {season if season is not None else 'N/A'}",
        f"CLAVES: entrenador | tecnico | mister | champions | ucl",
        f"CLUBES_MENCIONADOS: {clubs_str}",
    ]

    # Añade metadata simple como tokens (sin listas/dicts)
    md = obj.get("metadata") or {}
    if isinstance(md, dict):
        simple_md = []
        for k, v in md.items():
            if isinstance(v, (str, int, float, bool)) or v is None:
                simple_md.append(f"{k}={v}")
        if simple_md:
            header_lines.append("METADATA: " + " | ".join(simple_md))

    return "\n".join(header_lines) + "\n\n" + texto

# %%
# Config de chunking (ajústalo según tu caso)
CHUNK_SIZE = 900
CHUNK_OVERLAP = 150

splitter = RecursiveCharacterTextSplitter(
    chunk_size=CHUNK_SIZE,
    chunk_overlap=CHUNK_OVERLAP,
    separators=["\n\n", "\n", ". ", " ", ""],
)

known_clubs = sorted({t.get("team_name") for t in teams_data if t.get("team_name")})

def item_to_text(item: dict, source_name: str) -> str:
    """Convierte un registro a texto indexable (lo que irá al embedding)."""
    tipo = item.get("tipo", "")

    # ✅ 1) Render especializado por fuente (MEJORA RETRIEVAL)
    if source_name == "coaches":
        # Usa tu Celda 4 (ahora sí)
        return render_coach_doc(item, known_clubs=known_clubs).strip()

    if source_name == "finals":
        titulo = item.get("titulo") or ""
        texto  = item.get("texto")  or ""
        season = item.get("season_year")

        # --- extracción best-effort desde el título ---
        team_a = team_b = score = None
        m = re.search(
            r":\s*([A-Za-zÁÉÍÓÚÑáéíóúñ\s\.]+)\s+(\d+[-–]\d+)\s+([A-Za-zÁÉÍÓÚÑáéíóúñ\s\.]+)",
            titulo
        )
        if m:
            team_a = m.group(1).strip()
            score  = m.group(2).replace("–", "-").strip()
            team_b = m.group(3).strip()

        # --- ganador (solo si el texto lo dice explícitamente) ---
        winner = None
        mw = re.search(
            r"\b([A-ZÁÉÍÓÚÑ][A-Za-zÁÉÍÓÚÑáéíóúñ\s\.]+?)\s+se\s+impuso\b",
            texto
        )
        if mw:
            winner = mw.group(1).strip()

        # --- goleadores (best-effort, sin inventar) ---
        scorers = re.findall(
            r"\bgol(?:\s+decisivo)?\s+de\s+([A-ZÁÉÍÓÚÑ][a-záéíóúñ]+)",
            texto,
            flags=re.IGNORECASE
        )
        scorers = list(dict.fromkeys([s.strip() for s in scorers]))  # dedupe
        scorers_str = " | ".join(scorers) if scorers else None
        # --- header SOLO con datos reales ---
        header = [
            "CATEGORIA: final",
            f"TEMPORADA: {season}" if season is not None else None,
            f"TITULO: {titulo}" if titulo else None,
            f"FINAL_EQUIPO_A: {team_a}" if team_a else None,
            f"FINAL_EQUIPO_B: {team_b}" if team_b else None,
            f"MARCADOR: {score}" if score else None,
            f"GANADOR: {winner}" if winner else None,
            f"GOLEADORES: {scorers_str}" if scorers_str else None,
            "CLAVES: final | ganador | campeon | goles | goleadores | ucl | champions",
        ]

        header = [h for h in header if h]  # 🔹 elimina None

        return ("\n".join(header) + "\n\n" + texto).strip()


    # ✅ 2) QA (tu caso actual)
    titulo = item.get("titulo") or ""
    texto  = item.get("texto")  or ""

    if tipo == "qa":
        q = item.get("question", "") or item.get("pregunta", "") or ""
        a = item.get("answer", "")   or item.get("respuesta", "") or ""
        parts = []
        if titulo:
            parts.append(f"Título: {titulo}")
        if q:
            parts.append("Pregunta: " + q)
        if a:
            parts.append("Respuesta: " + a)
        if texto and not a:
            parts.append(texto)
        return "\n".join(parts).strip()

    # ✅ 3) Caso general (fact / otros)
    parts = []
    if titulo:
        parts.append(f"Título: {titulo}")
    if texto:
        parts.append(texto)
    else:
        parts.append(json.dumps(item, ensure_ascii=False))
    return "\n".join(parts).strip()


def build_docs_chunked(data_list: list[dict], source_name: str) -> list[Document]:
    """Crea Documents + los divide en chunks, manteniendo metadata."""
    out_docs: list[Document] = []

    for i, item in enumerate(data_list):
        categoria = item.get("categoria", source_name)
        tipo = item.get("tipo", "")
        doc_id = item.get("id", f"{source_name}_{i}")

        text = item_to_text(item, source_name)
        if not text:
            continue

        # Metadata base
        metadata = {
            "source": source_name,
            "categoria": categoria,
            "tipo": tipo,
            "id": doc_id,
            "season_year": item.get("season_year"),
        }

        # Si tu JSON lleva un campo 'metadata' interno, lo añadimos (sin pisar claves base)
        extra_meta = item.get("metadata") or {}
        if isinstance(extra_meta, dict):
            for k, v in extra_meta.items():
                if k not in metadata:
                    metadata[k] = v

        base_doc = Document(page_content=text, metadata=metadata)

        # Chunking
        chunks = splitter.split_documents([base_doc])
        for ci, ch in enumerate(chunks):
            ch.metadata = dict(ch.metadata)  # copia
            ch.metadata["chunk"] = ci
            ch.metadata["chunk_id"] = f"{doc_id}::chunk_{ci}"
            ch.metadata["parent_id"] = doc_id
            out_docs.append(ch)

    return out_docs


docs_finals  = build_docs_chunked(finals_data,  "finals")
docs_history = build_docs_chunked(history_data, "history")
docs_players = build_docs_chunked(players_data, "players")
docs_teams   = build_docs_chunked(teams_data,   "teams")
docs_coaches = build_docs_chunked(coaches_data, "coaches")

all_docs = docs_finals + docs_history + docs_players + docs_teams + docs_coaches
len(all_docs)
# Out:
# 217

# %%
# Embeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

from langchain_community.vectorstores.utils import filter_complex_metadata

# texts: List[str]
# metadatas: List[dict]
# ids: List[str] (opcional)

all_docs = filter_complex_metadata(all_docs)   # ✅ AQUÍ

# Vector store (en memoria). Si quieres persistencia:
# vectorstore = Chroma.from_documents(all_docs, embeddings, persist_directory="./chroma_db")
vectorstore = Chroma.from_documents(
    documents=all_docs,
    embedding=embeddings,
)

# Retrievers por categoría usando metadata.source
retriever_all = vectorstore.as_retriever(search_kwargs={"k": 6})

retriever_finals = vectorstore.as_retriever(
    search_kwargs={"k": 8, "filter": {"source": "finals"}}
)

retriever_history = vectorstore.as_retriever(
    search_kwargs={"k": 8, "filter": {"source": "history"}}
)

retriever_players = vectorstore.as_retriever(
    search_kwargs={"k": 8, "filter": {"source": "players"}}
)

retriever_teams = vectorstore.as_retriever(
    search_kwargs={"k": 8, "filter": {"source": "teams"}}
)

retriever_coaches = vectorstore.as_retriever(
    search_kwargs={"k": 8, "filter": {"source": "coaches"}}
)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14064\811903882.py:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
import re
import unicodedata

def _norm(s: str) -> str:
    """Normaliza para comparar (minúsculas, sin acentos, sin dobles espacios)."""
    if not s:
        return ""
    s = s.strip().lower()
    s = "".join(c for c in unicodedata.normalize("NFD", s) if unicodedata.category(c) != "Mn")
    s = re.sub(r"\s+", " ", s)
    return s

def extract_person_candidate(question: str) -> str | None:
    """
    Intenta extraer el nombre/entidad PERSONA del texto.
    Devuelve:
      - "pep guardiola" si detecta dos palabras con mayúscula
      - "guardiola" si detecta un apellido con mayúscula
      - None si no hay señales claras
    """
    # Dos palabras tipo "Pep Guardiola"
    m = re.search(r"\b([A-ZÁÉÍÓÚÑ][a-záéíóúñ]+)\s+([A-ZÁÉÍÓÚÑ][a-záéíóúñ]+)\b", question)
    if m:
        return _norm(m.group(0))

    # Una palabra tipo "Guardiola"
    m = re.search(r"\b([A-ZÁÉÍÓÚÑ][a-záéíóúñ]{3,})\b", question)
    if m:
        return _norm(m.group(1))

    return None

def has_person_name(question: str) -> bool:
    return extract_person_candidate(question) is not None

def choose_retrievers(question: str):
    """
    Devuelve una lista ORDENADA (prioridad real).
    REGLA: si hay persona -> coaches/players SIEMPRE primero.
    Teams/finals solo como soporte, history como comodín final.
    """
    q = _norm(question)

    wants_teams  = any(w in q for w in ["equipo", "equipos", "club", "clubes", "palmares", "palmarés", "titulos", "títulos"])
    wants_coach  = any(w in q for w in ["entrenador", "tecnico", "técnico", "mister", "míster", "coach"])
    wants_player = any(w in q for w in ["jugador", "goleador", "asistente", "asistencia", "maximo", "máximo", "apariciones", "partidos", "portero", "defensa", "delantero"])
    wants_finals = any(w in q for w in ["final", "semifinal", "cuartos", "octavos", "eliminatoria", "ronda", "ida", "vuelta"])
    wants_history = any(w in q for w in ["historia", "temporada", "campeon", "campeón", "gan", "titulo", "título"])

    person = has_person_name(question)

    # ✅ ORDEN INTENCIONADO
    if person:
        # Persona siempre manda
        order = [retriever_coaches, retriever_players]

        # Soportes SOLO si hace falta
        if wants_teams or wants_history:
            order += [retriever_teams]
        if wants_finals:
            order += [retriever_finals]

        # History = comodín final (ideal para QA)
        order += [retriever_history, retriever_all]
        return order

    # No persona -> heurística clásica, pero history siempre al final
    if wants_coach:
        return [retriever_coaches, retriever_all, retriever_history]

    if wants_player:
        return [retriever_players, retriever_all, retriever_history]

    if wants_teams:
        return [retriever_teams, retriever_all, retriever_history]

    if wants_finals:
        return [retriever_finals, retriever_all, retriever_history]

    if wants_history:
        return [retriever_history, retriever_all]

    return [retriever_all, retriever_history]

# %%
llm = ChatOllama(
    model=LLM_MODEL_NAME, temperature=0.1,  # opcional
)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14064\3881863704.py:1: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm = ChatOllama(

# %%
from urllib import response

from sympy import content


def ask_champions(question: str, k: int = 10, max_docs: int = 24):
    retrievers = choose_retrievers(question)

    def retrieve_docs(retriever, query: str):
        # Compatible con distintas versiones:
        if hasattr(retriever, "invoke"):
            return retriever.invoke(query)
        return retriever.get_relevant_documents(query)

    # --- 1) Query expansion (muy importante para perfiles de entrenadores) ---
    person = extract_person_candidate(question)  # de la caja 1
    expanded_queries = [question]

    if person:
        # Añadimos señales para que el embedding “apunte” a coaches
        expanded_queries += [
            f"{person} champions entrenador",
            f"{person} gano la champions entrenador",
            f"{person} perfil entrenador champions"
        ]

    # --- 2) Presupuesto por retriever (coaches primero, teams no ahoga) ---
    # Ajusta estos pesos si quieres
    def budget_for(r):
        if r is retriever_coaches:
            return max(4, k)              # coaches: fuerte
        if r is retriever_players:
            return max(3, k // 2)         # players: medio
        if r is retriever_finals:
            return max(3, k // 2)         # finals: medio
        if r is retriever_teams:
            return max(2, k // 3)         # teams: poco (evita ruido)
        if r is retriever_history:
            return max(2, k // 3)         # history: poco (comodín)
        return max(2, k // 3)

    docs = []
    seen = set()

    # --- 3) Recuperación multi-query por retriever (con dedupe) ---
    for r in retrievers:
        b = budget_for(r)
        collected = []

        for qx in expanded_queries:
            for d in retrieve_docs(r, qx):
                key = d.page_content.strip()
                if key not in seen:
                    seen.add(key)
                    collected.append(d)
                if len(collected) >= b:
                    break
            if len(collected) >= b:
                break

        docs.extend(collected)

        # corte duro para no inflar contexto
        if len(docs) >= max_docs:
            docs = docs[:max_docs]
            break

    # --- 4) Reordenado inteligente del contexto ---
    # Si hay persona: coach/player primero. Si no: fact primero como antes.
    def sort_key(doc):
        meta = doc.metadata or {}
        categoria = (meta.get("categoria") or "").lower()
        tipo = (meta.get("tipo") or "").lower()

        if person:
            # prioridad máxima: fact de coach/player
            if tipo == "fact" and categoria in ("coach", "player"):
                return (0, 0)
            # luego qa de coach/player
            if tipo == "qa" and categoria in ("coach", "player"):
                return (0, 1)
            # luego fact del resto
            if tipo == "fact":
                return (1, 0)
            # luego qa del resto
            if tipo == "qa":
                return (1, 1)
            return (2, 2)

        # sin persona (tu criterio original, pero un pelín más fino)
        if tipo == "fact":
            return (0, 0)
        if tipo == "qa":
            return (1, 0)
        return (2, 0)

    docs = sorted(docs, key=sort_key)

    print("\n📚 DOCUMENTOS RECUPERADOS:\n")
    for d in docs:
        meta = d.metadata or {}
        print(
            f"- source={meta.get('source')} | categoria={meta.get('categoria')} | tipo={meta.get('tipo')} "
            f"| id={meta.get('id')} | chunk={meta.get('chunk')} | season_year={meta.get('season_year')}"
        )
        print("  Extracto:", d.page_content[:180].replace("\n", " "), "...\n")

    # --- 5) Construir contexto con cabecera (útil para LLM) ---
    context_parts = []
    for d in docs:
        meta = d.metadata or {}
        header = (
            f"[source={meta.get('source')} | categoria={meta.get('categoria')} | tipo={meta.get('tipo')} "
            f"| id={meta.get('id')} | chunk_id={meta.get('chunk_id')}]\n"
        )
        context_parts.append(header + d.page_content)

    context_text = "\n\n---\n\n".join(context_parts)

    prompt = f"""
Eres un asistente de QA sobre la Champions League.
Responde SOLO con el CONTEXTO. Si no puedes sostener la respuesta con el CONTEXTO, responde EXACTAMENTE:
"No lo sé según estos datos".

REGLAS ANTI-INVENCIONES (OBLIGATORIAS)
- Cada afirmación debe estar apoyada por al menos un fragmento del CONTEXTO.
- NO añadas detalles (nombres, temporadas, números) si no aparecen textualmente en el CONTEXTO.
- Si el usuario pide una lista (equipos/temporadas/goleadores), devuelve SOLO los elementos explícitos.

RUTEADO
- Si aparece una PERSONA (entrenador/jugador), usa primero chunks con categoria=coach o categoria=player.
- Solo usa teams/finals/history como apoyo si faltan datos en el perfil.

INTERPRETACIÓN (solo si aparece en el CONTEXTO)
- "ganó la final" / "venció en la final" / "se impuso en la final" (de Champions) => "ganó la Champions" esa temporada.
- "campeón" / "conquistó el título" => ganó la Champions.

FORMATO (MUY IMPORTANTE)
1) Responde en formato compacto:
   - Si es una pregunta directa: 1–3 frases máximo.
   - Si es una lista: viñetas.
2) Al final añade una línea: "Fuentes:" y lista 1–3 referencias del contexto usando exactamente el formato:
   - [source=...|id=...|chunk_id=...]
3) No escribas introducciones largas ni contexto histórico extra.

CONTEXTO:
{context_text}

PREGUNTA:
{question}

RESPUESTA:
""".strip()

    response = llm.invoke(prompt)

    # Si el modelo se enrolla, recorta suavemente (opcional)
    content = response.content.strip()
    return content

    print("\n💬 RESPUESTA:\n")

# %%
ask_champions("¿Quién es el máximo goleador de la Champions según estos datos?")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_diego_simeone_profile | chunk=1 | season_year=None
#   Extracto: Diego Simeone es uno de los entrenadores mas competitivos de la Champions moderna. En este dataset aparece como entrenador del Atletico de Madrid, equipo al que ha dirigido en 82 p ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jupp_heynckes_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jupp Heynckes TITULO: Perfil historico de Jupp Heynckes en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_zinedine_zidane_profile | chunk=1 | season_year=None
#   Extracto: Zinedine Zidane es el unico entrenador que ha ganado tres Champions League consecutivas segun este dataset. Dirigio al Real Madrid en la Champions entre 2016 y 2021, acumulando 49  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_zinedine_zidane_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Zinedine Zidane TITULO: Perfil historico de Zinedine Zidane en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_thomas_tuchel_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Thomas Tuchel TITULO: Perfil historico de Thomas Tuchel en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=players | categoria=player | tipo=fact | id=player_andres_iniesta_profile | chunk=0 | season_year=None
#   Extracto: Título: Andrés Iniesta: generador de ventajas y asistencias Andrés Iniesta registra 29 asistencias en el dataset de Champions. Su peso no se mide solo en goles o pases de gol, sino ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=player_xavi_hernandez_profile | chunk=0 | season_year=None
#   Extracto: Título: Xavi Hernández: organizador de juego Xavi Hernández suma 30 asistencias en la Champions según los datos de acciones ofensivas. Aunque sus cifras goleadoras son menores, su  ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_assisters | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más asistencias en la Champions según el dataset Además de los goleadores, la base de datos recoge a los grandes asistentes de la era moderna. Según los datos ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_scorers | chunk=1 | season_year=None
#   Extracto: El dataset de Champions recoge a los grandes goleadores históricos de la competición moderna. Cristiano Ronaldo lidera la tabla con 140 goles en 183 partidos, seguido por Lionel Me ...
#
# - source=history | categoria=player | tipo=qa | id=players_qa_001_top_scorer | chunk=0 | season_year=None
#   Extracto: Pregunta: Quién es el máximo goleador histórico de la Champions según este dataset? Respuesta: Según el dataset de goleadores, el máximo goleador histórico de la Champions es Crist ...
#
# - source=history | categoria=player | tipo=qa | id=players_qa_002_top_assisters | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué jugadores destacan como asistentes en la Champions en estos datos? Respuesta: En los datos de acciones ofensivas destacan como grandes asistentes Ángel Di María con 4 ...
#
# - source=history | categoria=player | tipo=qa | id=players_qa_005_midfield_vs_forwards | chunk=0 | season_year=None
#   Extracto: Pregunta: Cómo complementan los centrocampistas creativos a los grandes goleadores en la Champions? Respuesta: Jugadores como Xavi, Iniesta, De Bruyne o Verratti no siempre lideran ...
#
# - source=finals | categoria=eliminatoria | tipo=fact | id=ucl_eliminatoria_2013_bayern_barcelona_7_0 | chunk=0 | season_year=2013
#   Extracto: CATEGORIA: final TEMPORADA: 2013 TITULO: Semifinal 2012-13: Bayern 7-0 Barcelona global — Cambio de ciclo FINAL_EQUIPO_A: Bayern FINAL_EQUIPO_B: Barcelona global MARCADOR: 7-0 GANA ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2021_chelsea_manchester_city | chunk=0 | season_year=2021
#   Extracto: CATEGORIA: final TEMPORADA: 2021 TITULO: 2020-21: Chelsea 1-0 Manchester City FINAL_EQUIPO_A: N/A FINAL_EQUIPO_B: N/A MARCADOR: N/A GANADOR: N/A GOLEADORES: Havertz CLAVES: final | ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_most_titles_by_country | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué país o qué liga ha ganado más Champions según este contexto? ...
#
#
# 💬 RESPUESTA:
#
#
# Según los datos proporcionados, el máximo goleador de la UEFA Champions League es **Cristiano Ronaldo** con **140 goles**.
#
# Le sigue de cerca **Lionel Messi** con **129 goles**.
# '\nSegún los datos proporcionados, el máximo goleador de la UEFA Champions League es **Cristiano Ronaldo** con **140 goles**.\n\nLe sigue de cerca **Lionel Messi** con **129 goles**.'

# %%
ask_champions("¿Qué equipo ha ganado más veces la Champions en este dataset?")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jupp_heynckes_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jupp Heynckes TITULO: Perfil historico de Jupp Heynckes en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_diego_simeone_profile | chunk=1 | season_year=None
#   Extracto: Diego Simeone es uno de los entrenadores mas competitivos de la Champions moderna. En este dataset aparece como entrenador del Atletico de Madrid, equipo al que ha dirigido en 82 p ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jurgen_klopp_profile | chunk=1 | season_year=None
#   Extracto: Jurgen Klopp es uno de los entrenadores mas reconocibles de la era moderna por su estilo basado en la presion alta y las transiciones intensas. En este dataset ha dirigido 100 part ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_thomas_tuchel_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Thomas Tuchel TITULO: Perfil historico de Thomas Tuchel en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_alex_ferguson_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Alex Ferguson TITULO: Perfil historico de Sir Alex Ferguson en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más partidos disputados en la Champions según el dataset ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=player_xavi_hernandez_profile | chunk=0 | season_year=None
#   Extracto: Título: Xavi Hernández: organizador de juego Xavi Hernández suma 30 asistencias en la Champions según los datos de acciones ofensivas. Aunque sus cifras goleadoras son menores, su  ...
#
# - source=players | categoria=player | tipo=fact | id=player_andres_iniesta_profile | chunk=0 | season_year=None
#   Extracto: Título: Andrés Iniesta: generador de ventajas y asistencias Andrés Iniesta registra 29 asistencias en el dataset de Champions. Su peso no se mide solo en goles o pases de gol, sino ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_assisters | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más asistencias en la Champions según el dataset Además de los goleadores, la base de datos recoge a los grandes asistentes de la era moderna. Según los datos ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Luis Enrique TITULO: Perfil historico de Luis Enrique en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl CLU ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Pep Guardiola TITULO: Perfil historico de Pep Guardiola en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_fabio_capello_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Fabio Capello TITULO: Perfil historico de Fabio Capello en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=history | categoria=coach | tipo=qa | id=coach_qa_001_mas_champions | chunk=0 | season_year=None
#   Extracto: Pregunta: Quien es el entrenador con mas Champions League ganadas? Respuesta: Segun este dataset, el entrenador con mas Champions League ganadas es Carlo Ancelotti, con un total de ...
#
# - source=teams | categoria=team | tipo=fact | id=team_bayern_munich_profile | chunk=2 | season_year=None
#   Extracto: . Ha marcado 632 goles y ha recibido 315. Es uno de los tres equipos con mas partidos y goles de la competicion desde 1992. Resumen de datos clave segun este dataset: titulos de Ch ...
#
# - source=teams | categoria=team | tipo=fact | id=team_barcelona_profile | chunk=2 | season_year=None
#   Extracto: . Ha marcado 626 goles y ha encajado 333. Es uno de los clubes con mas participaciones, partidos y goles en el periodo moderno. Resumen de datos clave segun este dataset: titulos d ...
#
# - source=teams | categoria=team | tipo=fact | id=team_real_madrid_profile | chunk=2 | season_year=None
#   Extracto: . En ese periodo ha marcado 698 goles y ha encajado 371. Es el equipo que mas partidos y mas goles ha conseguido en la competicion desde 1992, consolidando su imagen de rey de Euro ...
#
# - source=history | categoria=team | tipo=qa | id=team_qa_006_rank_campeones_por_titulos | chunk=0 | season_year=None
#   Extracto: Pregunta: Cuales son los equipos mas ganadores de la Champions en la era moderna segun este dataset? Respuesta: Segun este dataset de la era moderna, el equipo mas ganador es el Re ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_most_titles_by_country | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué país o qué liga ha ganado más Champions según este contexto? ...
#
#
# 💬 RESPUESTA:
#
#
# Okay, según el dataset proporcionado:
#
# El equipo que ha ganado más veces la UEFA Champions League es **Real Madrid**.
#
# En el dataset, aparece como:
#
# *   **Real Madrid**: Ganó **9** veces (títulos 1956, 1958, 1960, 1966, 2002, 2014, 2015, 2016, 2022).
# '\nOkay, según el dataset proporcionado:\n\nEl equipo que ha ganado más veces la UEFA Champions League es **Real Madrid**.\n\nEn el dataset, aparece como:\n\n*   **Real Madrid**: Ganó **9** veces (títulos 1956, 1958, 1960, 1966, 2002, 2014, 2015, 2016, 2022).'

# %%
ask_champions("¿Quién fue el entrenador del Real Madrid en la final de 2014 según estos datos?")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_zinedine_zidane_profile | chunk=1 | season_year=None
#   Extracto: Zinedine Zidane es el unico entrenador que ha ganado tres Champions League consecutivas segun este dataset. Dirigio al Real Madrid en la Champions entre 2016 y 2021, acumulando 49  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_diego_simeone_profile | chunk=1 | season_year=None
#   Extracto: Diego Simeone es uno de los entrenadores mas competitivos de la Champions moderna. En este dataset aparece como entrenador del Atletico de Madrid, equipo al que ha dirigido en 82 p ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jupp_heynckes_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jupp Heynckes TITULO: Perfil historico de Jupp Heynckes en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=1 | season_year=None
#   Extracto: Luis Enrique ha tenido dos etapas especialmente exitosas en la Champions League segun este dataset. En total se le atribuyen unos 60 partidos dirigidos en la competicion, principal ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_zinedine_zidane_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Zinedine Zidane TITULO: Perfil historico de Zinedine Zidane en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_fabio_capello_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Fabio Capello TITULO: Perfil historico de Fabio Capello en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_assisters | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más asistencias en la Champions según el dataset Además de los goleadores, la base de datos recoge a los grandes asistentes de la era moderna. Según los datos ...
#
# - source=players | categoria=player | tipo=fact | id=player_xavi_hernandez_profile | chunk=0 | season_year=None
#   Extracto: Título: Xavi Hernández: organizador de juego Xavi Hernández suma 30 asistencias en la Champions según los datos de acciones ofensivas. Aunque sus cifras goleadoras son menores, su  ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=2 | season_year=None
#   Extracto: . Según este ranking del dataset: Cristiano Ronaldo alcanza los 183 partidos de Champions, Iker Casillas 177, Thomas Müller 163 con el Bayern Múnich, Lionel Messi 163 entre sus dos ...
#
# - source=players | categoria=player | tipo=fact | id=player_andres_iniesta_profile | chunk=0 | season_year=None
#   Extracto: Título: Andrés Iniesta: generador de ventajas y asistencias Andrés Iniesta registra 29 asistencias en el dataset de Champions. Su peso no se mide solo en goles o pases de gol, sino ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2016_real_madrid_atletico | chunk=0 | season_year=2016
#   Extracto: CATEGORIA: final TEMPORADA: 2016 TITULO: 2015-16: Real Madrid 1-1 Atlético (5-3 pen) FINAL_EQUIPO_A: Real Madrid FINAL_EQUIPO_B: Atlético (5 MARCADOR: 1-1 GANADOR: N/A GOLEADORES:  ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2024_real_madrid_dortmund | chunk=0 | season_year=2024
#   Extracto: CATEGORIA: final TEMPORADA: 2024 TITULO: 2023-24: Real Madrid 2-0 Borussia Dortmund — La decimoquinta FINAL_EQUIPO_A: Real Madrid FINAL_EQUIPO_B: Borussia Dortmund MARCADOR: 2-0 GA ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2014_real_madrid_atletico | chunk=0 | season_year=2014
#   Extracto: CATEGORIA: final TEMPORADA: 2014 TITULO: 2013-14: Real Madrid 4-1 Atlético (prórroga) — El gol del minuto 93 FINAL_EQUIPO_A: Real Madrid FINAL_EQUIPO_B: Atlético (prórroga) MARCADO ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2017_real_madrid_juventus | chunk=0 | season_year=2017
#   Extracto: CATEGORIA: final TEMPORADA: 2017 TITULO: 2016-17: Real Madrid 4-1 Juventus — La primera defensa del título en la era Champions FINAL_EQUIPO_A: Real Madrid FINAL_EQUIPO_B: Juventus  ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2000_real_madrid_valencia | chunk=0 | season_year=2000
#   Extracto: CATEGORIA: final TEMPORADA: 2000 TITULO: 1999-2000: Real Madrid 3-0 Valencia — Primera final entre clubes del mismo país FINAL_EQUIPO_A: Real Madrid FINAL_EQUIPO_B: Valencia MARCAD ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_leagues_spanish_dominance | chunk=1 | season_year=None
#   Extracto: En este contexto histórico, los clubes españoles han tenido un peso enorme en la Champions League moderna. El Real Madrid, según los datos de equipos del dataset, alcanza los 15 tí ...
#
# - source=teams | categoria=team | tipo=fact | id=team_real_madrid_profile | chunk=0 | season_year=None
#   Extracto: Título: Perfil historico del Real Madrid en la Champions League ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_spanish_dominance_period | chunk=1 | season_year=None
#   Extracto: Respuesta: Dentro de este contexto, se suele hablar de un periodo de dominio español especialmente fuerte entre mediados de la década de 2000 y finales de la de 2010. En esos años, ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_spanish_dominance_period | chunk=2 | season_year=None
#   Extracto: . A esto se suma la presencia habitual del Atlético de Madrid en fases avanzadas, con finales épicas ante el propio Real Madrid. Sumados, estos éxitos hacen que durante más de una  ...
#
#
# 💬 RESPUESTA:
#
#
# The coach of Real Madrid in the 2014 Champions League final (against Atlético Madrid) was **Zinedine Zidane**.
# '\nThe coach of Real Madrid in the 2014 Champions League final (against Atlético Madrid) was **Zinedine Zidane**.'

# %%
ask_champions("¿Que jugador tiene más apariciones en la Champions League según estos datos?")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_alex_ferguson_profile | chunk=1 | season_year=None
#   Extracto: Sir Alex Ferguson es el entrenador con mas años consecutivos dirigiendo en la Champions League moderna. En este dataset, entreno al Manchester United en la competicion entre 1993 y ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=1 | season_year=None
#   Extracto: Luis Enrique ha tenido dos etapas especialmente exitosas en la Champions League segun este dataset. En total se le atribuyen unos 60 partidos dirigidos en la competicion, principal ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jupp_heynckes_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jupp Heynckes TITULO: Perfil historico de Jupp Heynckes en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_thomas_tuchel_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Thomas Tuchel TITULO: Perfil historico de Thomas Tuchel en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jose Mourinho TITULO: Perfil historico de Jose Mourinho en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_assisters | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más asistencias en la Champions según el dataset Además de los goleadores, la base de datos recoge a los grandes asistentes de la era moderna. Según los datos ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=player_andres_iniesta_profile | chunk=0 | season_year=None
#   Extracto: Título: Andrés Iniesta: generador de ventajas y asistencias Andrés Iniesta registra 29 asistencias en el dataset de Champions. Su peso no se mide solo en goles o pases de gol, sino ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más partidos disputados en la Champions según el dataset ...
#
# - source=players | categoria=player | tipo=fact | id=player_kevin_de_bruyne_profile | chunk=0 | season_year=None
#   Extracto: Título: Kevin De Bruyne: pasador de élite Kevin De Bruyne suma 27 asistencias en la Champions en el dataset, además de un buen número de goles. Es uno de los mejores pasadores larg ...
#
# - source=history | categoria=player | tipo=qa | id=players_qa_002_top_assisters | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué jugadores destacan como asistentes en la Champions en estos datos? Respuesta: En los datos de acciones ofensivas destacan como grandes asistentes Ángel Di María con 4 ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_leagues_france_portugal_netherlands | chunk=1 | season_year=None
#   Extracto: Además de las cuatro grandes ligas con más títulos en este contexto, hay países que desempeñan un papel clave como fabricas de talento y como protagonistas de momentos muy concreto ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_leagues_german_model | chunk=2 | season_year=None
#   Extracto: . El Borussia Dortmund, por ejemplo, es un club que forma y vende estrellas, mientras que el Bayern suele ser el destino final dentro de la propia Bundesliga para muchos de los mej ...
#
# - source=teams | categoria=team | tipo=fact | id=team_liverpool_profile | chunk=2 | season_year=None
#   Extracto: . Desde 2001 hasta 2025 ha jugado 163 partidos de Champions, con 88 victorias, 35 empates y 40 derrotas. Ha marcado 291 goles y ha encajado 160. Resumen de datos clave segun este d ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_overview_modern_era | chunk=2 | season_year=None
#   Extracto: . Cada final forma parte de una narrativa más amplia donde los estilos de juego, las generaciones de jugadores y los cambios de época en el fútbol europeo quedan reflejados con cla ...
#
# - source=teams | categoria=team | tipo=fact | id=team_manchester_united_profile | chunk=1 | season_year=None
#   Extracto: El Manchester United fue uno de los grandes dominadores europeos durante la era de Sir Alex Ferguson. En este dataset de la era Champions moderna, el United suma 2 titulos de Champ ...
#
#
# 💬 RESPUESTA:
#
#
# Según los datos proporcionados en la fuente **players_overview_top_appearances** (ID: players_overview_top_appearances), el jugador que ha disputado más partidos en la UEFA Champions League es **Cristiano Ronaldo**.
#
# ## Datos clave
#
# *   **Partidos (Appearances):** 181
# *   **Fuente:** player_cristiano_ronaldo_profile (ID: player_cristiano_ronaldo_profile) menciona su estadística de 181 partidos en la Champions League.
#
# ## Otros datos relevantes
#
# *   **Lionel Messi:** 163 partidos (ID: player_lionel_messi_profile, ID: players_overview_top_appearances)
# *   **Virgil van Dijk:** 152 partidos (ID: players_overview_top_appearances)
# *   **Karim Benzema:** 140 partidos (ID: players_overview_top_appearances)
#
# Por lo tanto, **Cristiano Ronaldo** es el jugador con más apariciones (181) en la UEFA Champions League según las fuentes dadas.
# '\nSegún los datos proporcionados en la fuente **players_overview_top_appearances** (ID: players_overview_top_appearances), el jugador que ha disputado más partidos en la UEFA Champions League es **Cristiano Ronaldo**.\n\n## Datos clave\n\n*   **Partidos (Appearances):** 181\n*   **Fuente:** player_cristiano_ronaldo_profile (ID: player_cristiano_ronaldo_profile) menciona su estadística de 181 partidos en la Champions League.\n\n## Otros datos relevantes\n\n*   **Lionel Messi:** 163 partidos (ID: player_lionel_messi_profile, ID: players_overview_top_appearances)\n*   **Virgil van Dijk:** 152 partidos (ID: players_overview_top_appearances)\n*   **Karim Benzema:** 140 partidos (ID: players_overview_top_appearances)\n\nPor lo tanto, **Cristiano Ronaldo** es el jugador con más apariciones (181) en la UEFA Champions League según las fuentes dadas.'

# %%
ask_champions("¿Quien metió gol en la final del 2012?")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=1 | season_year=None
#   Extracto: Luis Enrique ha tenido dos etapas especialmente exitosas en la Champions League segun este dataset. En total se le atribuyen unos 60 partidos dirigidos en la competicion, principal ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_fabio_capello_profile | chunk=1 | season_year=None
#   Extracto: Fabio Capello fue el tecnico del Milan en una de las etapas mas dominantes del futbol europeo. En la Champions moderna se le recuerda sobre todo por la final de la temporada 1993-9 ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_diego_simeone_profile | chunk=1 | season_year=None
#   Extracto: Diego Simeone es uno de los entrenadores mas competitivos de la Champions moderna. En este dataset aparece como entrenador del Atletico de Madrid, equipo al que ha dirigido en 82 p ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_zinedine_zidane_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Zinedine Zidane TITULO: Perfil historico de Zinedine Zidane en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_thomas_tuchel_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Thomas Tuchel TITULO: Perfil historico de Thomas Tuchel en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_scorers | chunk=1 | season_year=None
#   Extracto: El dataset de Champions recoge a los grandes goleadores históricos de la competición moderna. Cristiano Ronaldo lidera la tabla con 140 goles en 183 partidos, seguido por Lionel Me ...
#
# - source=players | categoria=player | tipo=fact | id=player_thomas_muller_profile | chunk=0 | season_year=None
#   Extracto: Título: Thomas Müller: goleador, asistente y especialista en espacios Thomas Müller suma 57 goles y 34 asistencias en 163 partidos de Champions. Ha transformado 8 penaltis. Sus núm ...
#
# - source=players | categoria=player | tipo=fact | id=player_karim_benzema_profile | chunk=0 | season_year=None
#   Extracto: Título: Karim Benzema: delantero total en Champions Karim Benzema suma 90 goles y 30 asistencias en 152 partidos de Champions según el dataset. Solo tiene 3 goles de penalti, lo qu ...
#
# - source=players | categoria=player | tipo=fact | id=player_andres_iniesta_profile | chunk=0 | season_year=None
#   Extracto: Título: Andrés Iniesta: generador de ventajas y asistencias Andrés Iniesta registra 29 asistencias en el dataset de Champions. Su peso no se mide solo en goles o pases de gol, sino ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2012_chelsea_bayern | chunk=0 | season_year=2012
#   Extracto: CATEGORIA: final TEMPORADA: 2012 TITULO: 2011-12: Chelsea 1-1 Bayern (4-3 pen) FINAL_EQUIPO_A: Chelsea FINAL_EQUIPO_B: Bayern (4 MARCADOR: 1-1 GANADOR: N/A GOLEADORES: N/A CLAVES:  ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2011_barcelona_manchester_united | chunk=0 | season_year=2011
#   Extracto: CATEGORIA: final TEMPORADA: 2011 TITULO: 2010-11: Barcelona 3-1 Manchester United — La obra maestra de Wembley FINAL_EQUIPO_A: Barcelona FINAL_EQUIPO_B: Manchester United MARCADOR: ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2013_bayern_dortmund | chunk=0 | season_year=2013
#   Extracto: CATEGORIA: final TEMPORADA: 2013 TITULO: 2012-13: Bayern 2-1 Borussia Dortmund — Final alemana intensa FINAL_EQUIPO_A: Bayern FINAL_EQUIPO_B: Borussia Dortmund MARCADOR: 2-1 GANADO ...
#
# - source=finals | categoria=eliminatoria | tipo=fact | id=ucl_eliminatoria_2013_bayern_barcelona_7_0 | chunk=0 | season_year=2013
#   Extracto: CATEGORIA: final TEMPORADA: 2013 TITULO: Semifinal 2012-13: Bayern 7-0 Barcelona global — Cambio de ciclo FINAL_EQUIPO_A: Bayern FINAL_EQUIPO_B: Barcelona global MARCADOR: 7-0 GANA ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_rules_away_goals | chunk=2 | season_year=2022
#   Extracto: . Sin embargo, en las últimas temporadas de este contexto histórico la UEFA decide eliminar el valor doble del gol de visitante. A partir de ese momento, si una eliminatoria termin ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2010_inter_bayern | chunk=0 | season_year=2010
#   Extracto: CATEGORIA: final TEMPORADA: 2010 TITULO: 2009-10: Inter 2-0 Bayern — El triplete de Mourinho FINAL_EQUIPO_A: Inter FINAL_EQUIPO_B: Bayern MARCADOR: 2-0 GANADOR: N/A GOLEADORES: N/A ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_most_titles_by_country | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué país o qué liga ha ganado más Champions según este contexto? ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_spanish_dominance_period | chunk=0 | season_year=None
#   Extracto: Pregunta: Cuándo se puede hablar de un periodo de dominio español en la Champions dentro de este contexto? ...
#
# - source=finals | categoria=eliminatoria | tipo=contexto | id=ucl_eliminatoria_2011_bayern_inter | chunk=0 | season_year=2011
#   Extracto: CATEGORIA: final TEMPORADA: 2011 TITULO: Octavos 2010-11: Inter 3-2 Bayern — Decidido por goles fuera FINAL_EQUIPO_A: Inter FINAL_EQUIPO_B: Bayern MARCADOR: 3-2 GANADOR: N/A GOLEAD ...
#
#
# 💬 RESPUESTA:
#
#
# Based on the information provided, the goalscorers in the 2012 UEFA Champions League final were:
#
# *   **Franz Müller** (Bayern Munich)
# *   **Didier Drogba** (Chelsea)
#
# The final ended 1-1 after extra time, with Bayern Munich winning on penalties.
# '\nBased on the information provided, the goalscorers in the 2012 UEFA Champions League final were:\n\n*   **Franz Müller** (Bayern Munich)\n*   **Didier Drogba** (Chelsea)\n\nThe final ended 1-1 after extra time, with Bayern Munich winning on penalties.'

# %%
ask_champions("Dime todos los jugadores que hayan marcado en la final de la Champions en la temporada 2011-2012 según estos datos")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_diego_simeone_profile | chunk=1 | season_year=None
#   Extracto: Diego Simeone es uno de los entrenadores mas competitivos de la Champions moderna. En este dataset aparece como entrenador del Atletico de Madrid, equipo al que ha dirigido en 82 p ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jurgen_klopp_profile | chunk=1 | season_year=None
#   Extracto: Jurgen Klopp es uno de los entrenadores mas reconocibles de la era moderna por su estilo basado en la presion alta y las transiciones intensas. En este dataset ha dirigido 100 part ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=1 | season_year=None
#   Extracto: Luis Enrique ha tenido dos etapas especialmente exitosas en la Champions League segun este dataset. En total se le atribuyen unos 60 partidos dirigidos en la competicion, principal ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jupp_heynckes_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jupp Heynckes TITULO: Perfil historico de Jupp Heynckes en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_zinedine_zidane_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Zinedine Zidane TITULO: Perfil historico de Zinedine Zidane en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_thomas_tuchel_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Thomas Tuchel TITULO: Perfil historico de Thomas Tuchel en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_assisters | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más asistencias en la Champions según el dataset Además de los goleadores, la base de datos recoge a los grandes asistentes de la era moderna. Según los datos ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más partidos disputados en la Champions según el dataset ...
#
# - source=players | categoria=player | tipo=fact | id=player_kevin_de_bruyne_profile | chunk=0 | season_year=None
#   Extracto: Título: Kevin De Bruyne: pasador de élite Kevin De Bruyne suma 27 asistencias en la Champions en el dataset, además de un buen número de goles. Es uno de los mejores pasadores larg ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=player_andres_iniesta_profile | chunk=0 | season_year=None
#   Extracto: Título: Andrés Iniesta: generador de ventajas y asistencias Andrés Iniesta registra 29 asistencias en el dataset de Champions. Su peso no se mide solo en goles o pases de gol, sino ...
#
# - source=history | categoria=player | tipo=qa | id=players_qa_002_top_assisters | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué jugadores destacan como asistentes en la Champions en estos datos? Respuesta: En los datos de acciones ofensivas destacan como grandes asistentes Ángel Di María con 4 ...
#
# - source=teams | categoria=team | tipo=fact | id=team_psg_profile | chunk=2 | season_year=None
#   Extracto: . Desde 1994 hasta 2025 ha jugado 166 partidos de Champions, con 90 victorias, 29 empates y 47 derrotas. Ha marcado 328 goles y ha recibido 189. Resumen de datos clave segun este d ...
#
# - source=teams | categoria=team | tipo=fact | id=team_liverpool_profile | chunk=2 | season_year=None
#   Extracto: . Desde 2001 hasta 2025 ha jugado 163 partidos de Champions, con 88 victorias, 35 empates y 40 derrotas. Ha marcado 291 goles y ha encajado 160. Resumen de datos clave segun este d ...
#
# - source=teams | categoria=team | tipo=fact | id=team_porto_profile | chunk=0 | season_year=None
#   Extracto: Título: Perfil historico del Porto en la Champions League El Porto es un club que destaca por su scouting y su capacidad para desarrollar jugadores y luego traspasarlos. En la Cham ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_overview_modern_era | chunk=1 | season_year=None
#   Extracto: Las finales de la Champions League representan el punto culminante de cada temporada y, dentro de la era moderna, se han convertido en algunos de los eventos deportivos más seguido ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2012_chelsea_bayern | chunk=0 | season_year=2012
#   Extracto: CATEGORIA: final TEMPORADA: 2012 TITULO: 2011-12: Chelsea 1-1 Bayern (4-3 pen) FINAL_EQUIPO_A: Chelsea FINAL_EQUIPO_B: Bayern (4 MARCADOR: 1-1 GANADOR: N/A GOLEADORES: N/A CLAVES:  ...
#
# - source=finals | categoria=eliminatoria | tipo=fact | id=ucl_eliminatoria_2013_bayern_barcelona_7_0 | chunk=0 | season_year=2013
#   Extracto: CATEGORIA: final TEMPORADA: 2013 TITULO: Semifinal 2012-13: Bayern 7-0 Barcelona global — Cambio de ciclo FINAL_EQUIPO_A: Bayern FINAL_EQUIPO_B: Barcelona global MARCADOR: 7-0 GANA ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2011_barcelona_manchester_united | chunk=0 | season_year=2011
#   Extracto: CATEGORIA: final TEMPORADA: 2011 TITULO: 2010-11: Barcelona 3-1 Manchester United — La obra maestra de Wembley FINAL_EQUIPO_A: Barcelona FINAL_EQUIPO_B: Manchester United MARCADOR: ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2013_bayern_dortmund | chunk=0 | season_year=2013
#   Extracto: CATEGORIA: final TEMPORADA: 2013 TITULO: 2012-13: Bayern 2-1 Borussia Dortmund — Final alemana intensa FINAL_EQUIPO_A: Bayern FINAL_EQUIPO_B: Borussia Dortmund MARCADOR: 2-1 GANADO ...
#
#
# 💬 RESPUESTA:
#
#
# Okay, the 2011-2012 UEFA Champions League Final was between **Chelsea** and **Bayern Munich**.
#
# The match itself was played after extra time and ended **1-1**.
#
# Here are the two goals scored during the 90 minutes plus extra time:
#
# 1.  **Bayern Munich** scored first via **Franck Ribery**'s pass and **Mats Hummels**' header (74th minute).
# 2.  **Chelsea** equalized through **Didier Drogba**'s close-range header (81st minute).
#
# Therefore, the players who scored goals in the final were:
#
# *   **Franck Ribery**
# *   **Mats Hummels**
# *   **Didier Drogba**
#
# **Important Note:** The match went to a penalty shootout where Chelsea won (Drogba scored in the shootout), but the question asks about goals scored *in the match* (presumably during the 90 minutes plus extra time), not penalties.
# "\nOkay, the 2011-2012 UEFA Champions League Final was between **Chelsea** and **Bayern Munich**.\n\nThe match itself was played after extra time and ended **1-1**.\n\nHere are the two goals scored during the 90 minutes plus extra time:\n\n1.  **Bayern Munich** scored first via **Franck Ribery**'s pass and **Mats Hummels**' header (74th minute).\n2.  **Chelsea** equalized through **Didier Drogba**'s close-range header (81st minute).\n\nTherefore, the players who scored goals in the final were:\n\n*   **Franck Ribery**\n*   **Mats Hummels**\n*   **Didier Drogba**\n\n**Important Note:** The match went to a penalty shootout where Chelsea won (Drogba scored in the shootout), but the question asks about goals scored *in the match* (presumably during the 90 minutes plus extra time), not penalties."

# %%
ask_champions("¿Qué equipo ganó la Champions League en la temporada 2011-2012 según estos datos?")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jurgen_klopp_profile | chunk=1 | season_year=None
#   Extracto: Jurgen Klopp es uno de los entrenadores mas reconocibles de la era moderna por su estilo basado en la presion alta y las transiciones intensas. En este dataset ha dirigido 100 part ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jupp_heynckes_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jupp Heynckes TITULO: Perfil historico de Jupp Heynckes en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_rafa_benitez_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Rafael Benitez TITULO: Perfil historico de Rafael Benitez en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_thomas_tuchel_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Thomas Tuchel TITULO: Perfil historico de Thomas Tuchel en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jose Mourinho TITULO: Perfil historico de Jose Mourinho en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más partidos disputados en la Champions según el dataset ...
#
# - source=players | categoria=player | tipo=fact | id=player_xavi_hernandez_profile | chunk=0 | season_year=None
#   Extracto: Título: Xavi Hernández: organizador de juego Xavi Hernández suma 30 asistencias en la Champions según los datos de acciones ofensivas. Aunque sus cifras goleadoras son menores, su  ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=2 | season_year=None
#   Extracto: . Según este ranking del dataset: Cristiano Ronaldo alcanza los 183 partidos de Champions, Iker Casillas 177, Thomas Müller 163 con el Bayern Múnich, Lionel Messi 163 entre sus dos ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_goalkeepers | chunk=2 | season_year=None
#   Extracto: . También destacan Víctor Valdés, Jan Oblak, Dida, Oliver Kahn y Ederson, todos con más de 30 porterías a cero en la competición. Según el detalle numérico del dataset, Manuel Neue ...
#
# - source=history | categoria=coach | tipo=qa | id=coach_qa_001_mas_champions | chunk=0 | season_year=None
#   Extracto: Pregunta: Quien es el entrenador con mas Champions League ganadas? Respuesta: Segun este dataset, el entrenador con mas Champions League ganadas es Carlo Ancelotti, con un total de ...
#
# - source=teams | categoria=team | tipo=fact | id=team_inter_profile | chunk=1 | season_year=None
#   Extracto: El Inter de Milan ha tenido etapas irregulares en la Champions, pero con picos muy altos. El mas destacado en la era moderna es el triplete de 2010 con Jose Mourinho, cuando gano l ...
#
# - source=teams | categoria=team | tipo=fact | id=team_juventus_profile | chunk=0 | season_year=None
#   Extracto: Título: Perfil historico de la Juventus en la Champions League La Juventus es uno de los grandes clubes de Italia y de Europa, conocida por su solidez defensiva y su regularidad en ...
#
# - source=teams | categoria=team | tipo=fact | id=team_barcelona_profile | chunk=1 | season_year=None
#   Extracto: El Barcelona ha sido uno de los equipos mas influyentes tacticamente en la era moderna de la Champions League. Su identidad esta marcada por el juego de posicion, la posesion alta  ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2009_barcelona_manchester_united | chunk=0 | season_year=2009
#   Extracto: CATEGORIA: final TEMPORADA: 2009 TITULO: 2008-09: Barcelona 2-0 Manchester United — El inicio de una era FINAL_EQUIPO_A: Barcelona FINAL_EQUIPO_B: Manchester United MARCADOR: 2-0 G ...
#
# - source=finals | categoria=final | tipo=fact | id=ucl_finals_2017_real_madrid_juventus | chunk=0 | season_year=2017
#   Extracto: CATEGORIA: final TEMPORADA: 2017 TITULO: 2016-17: Real Madrid 4-1 Juventus — La primera defensa del título en la era Champions FINAL_EQUIPO_A: Real Madrid FINAL_EQUIPO_B: Juventus  ...
#
# - source=finals | categoria=eliminatoria | tipo=fact | id=ucl_eliminatoria_2013_bayern_barcelona_7_0 | chunk=0 | season_year=2013
#   Extracto: CATEGORIA: final TEMPORADA: 2013 TITULO: Semifinal 2012-13: Bayern 7-0 Barcelona global — Cambio de ciclo FINAL_EQUIPO_A: Bayern FINAL_EQUIPO_B: Barcelona global MARCADOR: 7-0 GANA ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_most_titles_by_country | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué país o qué liga ha ganado más Champions según este contexto? ...
#
# - source=history | categoria=team | tipo=qa | id=team_qa_001_mas_partidos_champions | chunk=0 | season_year=None
#   Extracto: Pregunta: Que equipo ha disputado mas partidos de Champions League desde 1992? Respuesta: Desde el inicio de la era moderna, segun este dataset, el Real Madrid es el equipo que ha  ...
#
#
# 💬 RESPUESTA:
#
#
# El equipo que ganó la **Champions League en la temporada 2011-2012 fue el Real Madrid**.
#
# Aunque en los datos proporcionados no hay una entrada específica para la final de 2012, la información sobre los títulos de los equipos y el historial del Real Madrid como máximo goleador y participante en más finales confirma que fue el Real Madrid el que se alzó con el trofeo en esa edición.
# '\nEl equipo que ganó la **Champions League en la temporada 2011-2012 fue el Real Madrid**.\n\nAunque en los datos proporcionados no hay una entrada específica para la final de 2012, la información sobre los títulos de los equipos y el historial del Real Madrid como máximo goleador y participante en más finales confirma que fue el Real Madrid el que se alzó con el trofeo en esa edición.'

# %%
ask_champions("¿El Marsella ganó la Champions alguna vez?")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_zinedine_zidane_profile | chunk=1 | season_year=None
#   Extracto: Zinedine Zidane es el unico entrenador que ha ganado tres Champions League consecutivas segun este dataset. Dirigio al Real Madrid en la Champions entre 2016 y 2021, acumulando 49  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_ottmar_hitzfeld_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Ottmar Hitzfeld TITULO: Perfil historico de Ottmar Hitzfeld en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jupp_heynckes_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Jupp Heynckes TITULO: Perfil historico de Jupp Heynckes en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_fabio_capello_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Fabio Capello TITULO: Perfil historico de Fabio Capello en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Luis Enrique TITULO: Perfil historico de Luis Enrique en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl CLU ...
#
# - source=players | categoria=player | tipo=fact | id=player_xavi_hernandez_profile | chunk=0 | season_year=None
#   Extracto: Título: Xavi Hernández: organizador de juego Xavi Hernández suma 30 asistencias en la Champions según los datos de acciones ofensivas. Aunque sus cifras goleadoras son menores, su  ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=0 | season_year=None
#   Extracto: Título: Jugadores con más partidos disputados en la Champions según el dataset ...
#
# - source=players | categoria=player | tipo=fact | id=player_angel_di_maria_profile | chunk=0 | season_year=None
#   Extracto: Título: Ángel Di María: uno de los grandes asistentes de la Champions Ángel Di María es uno de los jugadores con más asistencias en el dataset de Champions, con 41 pases de gol acu ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=players | categoria=player | tipo=fact | id=player_andres_iniesta_profile | chunk=0 | season_year=None
#   Extracto: Título: Andrés Iniesta: generador de ventajas y asistencias Andrés Iniesta registra 29 asistencias en el dataset de Champions. Su peso no se mide solo en goles o pases de gol, sino ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Carlo Ancelotti TITULO: Perfil historico de Carlo Ancelotti en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=history | categoria=coach | tipo=qa | id=coach_qa_001_mas_champions | chunk=0 | season_year=None
#   Extracto: Pregunta: Quien es el entrenador con mas Champions League ganadas? Respuesta: Segun este dataset, el entrenador con mas Champions League ganadas es Carlo Ancelotti, con un total de ...
#
# - source=teams | categoria=team | tipo=fact | id=team_atletico_de_madrid_profile | chunk=0 | season_year=None
#   Extracto: Título: Perfil historico del Atletico de Madrid en la Champions League ...
#
# - source=teams | categoria=team | tipo=fact | id=team_real_madrid_profile | chunk=1 | season_year=None
#   Extracto: El Real Madrid es el club mas exitoso de la historia de la Champions League en la era moderna segun este dataset. En este periodo moderno, el conjunto blanco suma 9 titulos de Cham ...
#
# - source=teams | categoria=team | tipo=fact | id=team_barcelona_profile | chunk=2 | season_year=None
#   Extracto: . Ha marcado 626 goles y ha encajado 333. Es uno de los clubes con mas participaciones, partidos y goles en el periodo moderno. Resumen de datos clave segun este dataset: titulos d ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_leagues_italian_tradition | chunk=2 | season_year=None
#   Extracto: . Milan, Inter y Juventus protagonizan finales tanto ganadas como perdidas frente a rivales españoles, ingleses y alemanes, y ayudan a contar la historia de la Champions como un ch ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_most_titles_by_country | chunk=0 | season_year=None
#   Extracto: Pregunta: Qué país o qué liga ha ganado más Champions según este contexto? ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_spanish_dominance_period | chunk=0 | season_year=None
#   Extracto: Pregunta: Cuándo se puede hablar de un periodo de dominio español en la Champions dentro de este contexto? ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_away_goals_rule | chunk=0 | season_year=None
#   Extracto: Pregunta: Cómo afectaba la norma del gol de visitante a las eliminatorias de Champions y qué cambió al eliminarla? ...
#
#
# 💬 RESPUESTA:
#
#
# ¡Sí! El **Marsella** (del **París** francés, aunque el nombre completo es **Football Club de Marseille**) **sí ha ganado tres veces la UEFA Champions League** (ahora conocida como la UEFA Europa League, aunque el torneo en sí no ha cambiado de nombre):
#
# 1. **1993**: Derrotó al AC Milán en la final de Roma (2-0).
# 2. **1996**: Se impuso al Ajax en el Stade de France (1-0).
# 3. **1998**: Venció al Manchester United en el Stade Vélodrome (3-0).
#
# Sin embargo, **el actual campeón es el Paris Saint-Germain (PSG)**, que ganó la edición de 2023-2024. El PSG también es un club francés, pero de París, no de Marsella.
#
# En resumen: **el Marsella ganó tres veces la Champions League**, pero el PSG ha ganado recientemente. 😊
# '\n¡Sí! El **Marsella** (del **París** francés, aunque el nombre completo es **Football Club de Marseille**) **sí ha ganado tres veces la UEFA Champions League** (ahora conocida como la UEFA Europa League, aunque el torneo en sí no ha cambiado de nombre):\n\n1. **1993**: Derrotó al AC Milán en la final de Roma (2-0).\n2. **1996**: Se impuso al Ajax en el Stade de France (1-0).\n3. **1998**: Venció al Manchester United en el Stade Vélodrome (3-0).\n\nSin embargo, **el actual campeón es el Paris Saint-Germain (PSG)**, que ganó la edición de 2023-2024. El PSG también es un club francés, pero de París, no de Marsella.\n\nEn resumen: **el Marsella ganó tres veces la Champions League**, pero el PSG ha ganado recientemente. 😊'

# %%
ask_champions("Dime todos los equipos con los que Pep Guardiola ha ganado la Champions League según estos datos")
# Out:
# 📚 DOCUMENTOS RECUPERADOS:
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=1 | season_year=None
#   Extracto: Pep Guardiola es uno de los entrenadores mas influyentes del futbol moderno y una referencia del juego de posicion. En este dataset ha dirigido 167 partidos de Champions League con ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_vicente_del_bosque_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Vicente del Bosque TITULO: Perfil historico de Vicente del Bosque en Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions  ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jose_mourinho_profile | chunk=1 | season_year=None
#   Extracto: Jose Mourinho es uno de los entrenadores mas estrategicos y reconocibles de la Champions League. En este dataset ha dirigido 151 partidos en la competicion con seis equipos distint ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_roberto_di_matteo_profile | chunk=1 | season_year=None
#   Extracto: Roberto Di Matteo es recordado por su breve pero historica etapa como entrenador del Chelsea en la Champions League. En este dataset aparece con unos 20 partidos dirigidos en la co ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_pep_guardiola_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Pep Guardiola TITULO: Perfil historico de Pep Guardiola en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=1 | season_year=None
#   Extracto: Luis Enrique ha tenido dos etapas especialmente exitosas en la Champions League segun este dataset. En total se le atribuyen unos 60 partidos dirigidos en la competicion, principal ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_carlo_ancelotti_profile | chunk=1 | season_year=None
#   Extracto: Carlo Ancelotti es considerado el entrenador mas exitoso de la historia de la Champions League segun este dataset. Ha dirigido un total de 191 partidos en la competicion, repartido ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_jurgen_klopp_profile | chunk=1 | season_year=None
#   Extracto: Jurgen Klopp es uno de los entrenadores mas reconocibles de la era moderna por su estilo basado en la presion alta y las transiciones intensas. En este dataset ha dirigido 100 part ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_luis_enrique_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Luis Enrique TITULO: Perfil historico de Luis Enrique en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl CLU ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_alex_ferguson_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Alex Ferguson TITULO: Perfil historico de Sir Alex Ferguson en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | u ...
#
# - source=players | categoria=player | tipo=fact | id=player_thierry_henry_profile | chunk=0 | season_year=None
#   Extracto: Título: Thierry Henry: delantero completo en Champions Thierry Henry registra 50 goles y 24 asistencias en 112 partidos de Champions en el dataset, con 3 penaltis convertidos. Sus  ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_goalkeepers | chunk=3 | season_year=None
#   Extracto: . Petr Cech, con tres clubes, juega 111 partidos, deja su portería a cero en 49 ocasiones, encaja 115 goles y recibe un gol cada 86 minutos. Víctor Valdés, en el FC Barcelona, disp ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_appearances | chunk=1 | season_year=None
#   Extracto: El dataset incluye también a los jugadores con más partidos disputados en la Champions League moderna. Cristiano Ronaldo es el futbolista con más apariciones, con 183 partidos, seg ...
#
# - source=players | categoria=player | tipo=fact | id=players_overview_top_goalkeepers | chunk=1 | season_year=None
#   Extracto: El dataset de porteros refleja a varios guardametas legendarios de la Champions. Manuel Neuer suma 63 porterías a cero en 155 partidos y encaja 150 goles, con una media de 92 minut ...
#
# - source=players | categoria=player | tipo=fact | id=player_lionel_messi_profile | chunk=0 | season_year=None
#   Extracto: Título: Lionel Messi en la Champions: goleador y generador de juego Lionel Messi suma 129 goles en 163 partidos de Champions en el dataset, con 45 asistencias y 18 penaltis transfo ...
#
# - source=coaches | categoria=coach | tipo=fact | id=coach_thomas_tuchel_profile | chunk=0 | season_year=None
#   Extracto: CATEGORIA: coach ENTRENADOR: Thomas Tuchel TITULO: Perfil historico de Thomas Tuchel en la Champions League TEMPORADA: N/A CLAVES: entrenador | tecnico | mister | champions | ucl C ...
#
# - source=history | categoria=coach | tipo=qa | id=coach_qa_001_mas_champions | chunk=0 | season_year=None
#   Extracto: Pregunta: Quien es el entrenador con mas Champions League ganadas? Respuesta: Segun este dataset, el entrenador con mas Champions League ganadas es Carlo Ancelotti, con un total de ...
#
# - source=teams | categoria=team | tipo=fact | id=team_manchester_city_profile | chunk=1 | season_year=None
#   Extracto: El Manchester City es un proyecto de largo plazo que se consolida en la Champions durante la era Guardiola. En este dataset se recoge que el City ha ganado 1 Champions League en la ...
#
# - source=teams | categoria=team | tipo=fact | id=team_barcelona_profile | chunk=1 | season_year=None
#   Extracto: El Barcelona ha sido uno de los equipos mas influyentes tacticamente en la era moderna de la Champions League. Su identidad esta marcada por el juego de posicion, la posesion alta  ...
#
# - source=teams | categoria=team | tipo=fact | id=team_chelsea_profile | chunk=1 | season_year=None
#   Extracto: El Chelsea se convierte en potencia europea en el siglo XXI, combinando grandes inversiones con una identidad competitiva y solida. En este dataset de la era moderna, el Chelsea su ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_overview_era_moderna | chunk=1 | season_year=None
#   Extracto: La era moderna de la Champions League comienza en la temporada 1992-93, cuando la antigua Copa de Europa se transforma en un formato con fase de grupos y se refuerza la marca Champ ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_leagues_english_power | chunk=1 | season_year=None
#   Extracto: Los clubes ingleses también tienen un papel protagonista en la historia moderna de la Champions. Según los datos del contexto de equipos, el Liverpool suma 6 títulos, el Manchester ...
#
# - source=history | categoria=history | tipo=fact | id=ucl_history_economy_superclubs | chunk=1 | season_year=None
#   Extracto: Otro elemento clave en la historia moderna de la Champions es la aparición de los llamados superclubs: equipos con ingresos muy elevados, presencia global de marca y capacidad para ...
#
# - source=history | categoria=history | tipo=qa | id=ucl_history_qa_most_titles_by_country | chunk=1 | season_year=None
#   Extracto: Respuesta: Según este contexto de datos, los clubes españoles son los que más Champions acumulan en la era moderna ampliada. El Real Madrid suma 15 títulos y el Barcelona 5, lo que ...
#
#
# 💬 RESPUESTA:
#
#
# El usuario ha proporcionado datos que mencionan a Pep Guardiola como entrenador de tres equipos diferentes que han ganado la Champions League en la era moderna:
#
# 1.  **Barcelona:** Ganó en 2009 y 2011.
# 2.  **Manchester City:** Ganó en 2022-2023.
# 3.  **Bayern Munich:** Ganó en 2013.
#
# **Entonces, según la información proporcionada, Pep Guardiola ha ganado la Champions League con 3 equipos diferentes.**
# '\nEl usuario ha proporcionado datos que mencionan a Pep Guardiola como entrenador de tres equipos diferentes que han ganado la Champions League en la era moderna:\n\n1.  **Barcelona:** Ganó en 2009 y 2011.\n2.  **Manchester City:** Ganó en 2022-2023.\n3.  **Bayern Munich:** Ganó en 2013.\n\n**Entonces, según la información proporcionada, Pep Guardiola ha ganado la Champions League con 3 equipos diferentes.**'
